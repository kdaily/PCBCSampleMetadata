# %%
import synapseclient
syn = synapseclient.Synapse()
syn.login(silent=True)

# %%
import PCBCAnnotations

# %% [markdown]
# Get the normalized mRNA matrix.

# %%
matobj = PCBCAnnotations.ProcessedMRNAMatrix(syn=syn, synid='syn2701943')

# %%
reload(PCBCAnnotations)
# Out:
# <module 'PCBCAnnotations' from 'PCBCAnnotations.py'>

# %%
pdf = PCBCAnnotations.PandaQueryTable(syn=syn, table_id='syn2767694')

# %%
pda
# Out:
#        C4_Cell_Line_ID      Diffname_short                        UID  \
# 0                 None                None                       None
# 1                 None                None                       None
# 2                 None                None                       None
# 3                 None                None                       None
# 4                 None                None                       None
# 5                 None                None                       None
# 6                 None                None                       None
# 7                 None                None                       None
# 8                 None                None                       None
# 9                 None                None                       None
# 10                None                None                       None
# 11                None                None                       None
# ...
