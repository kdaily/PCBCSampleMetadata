# %% [markdown]
# This notebook updates file annotations for the PCBC project for those that can be mapped by C4_Cell_Line_ID.
#
# There are two required file annotations for any assay file uploaded to Synapse:
#
# * `C4_Cell_Line_ID` - Used to join to metadata
# * `dataType` - `Karyotype`, `CNV`, or `Teratoma`
#
# This script uses the `dataType` field to get assay-specific files (using a query lookup dictionary `assayToQuery`), and then the `C4_Cell_Line_ID` to merge existing file annotations and the table metadata (which is obtained through a lookup dictionary `assayToMetadataTable`.

# %%
import sys
import pandas as pd
import numpy
import logging

logger = logging.getLogger('pcbc update annots')
logger.setLevel(logging.DEBUG)

from multiprocessing.dummy import Pool
mp = Pool(10)

import synapseHelpers
import synapseclient

syn = synapseclient.Synapse(skip_checks=True)
syn.login(silent=True)

dataTypes = ['Karyotype', 'CNV', 'Teratoma']

dataTypesToMetadataTable = dict(Karyotype='syn2767694',
                                CNV='syn2767694',
                                Teratoma='syn2767694')

dataTypesToQuery = dict(Karyotype="select id,C4_Cell_Line_ID from file where projectId=='syn1773109' AND dataType=='Karyotype'",
                        CNV="select id,C4_Cell_Line_ID from file where projectId=='syn1773109' AND dataType=='CNV'",
                        Teratoma="select id,C4_Cell_Line_ID from file where projectId=='syn1773109' AND dataType=='Teratoma'")

# %%
def fixDict(d):
    """Fix dictionaries having .
    
    """
    
    newd = {}
    for k, v in d.iteritems():
        tmp = {}
        for k2, v2 in v.iteritems():
            if v2 is list:
                tmp[k2] = v2
            else:
                try:
                    if not numpy.isnan(v2):
                        tmp[k2] = v2
                except TypeError:
                    tmp[k2] = v2
        newd[k] = tmp
    return newd

def updateDict(a, b):
    """Remove synapse fields from Synapse query on file annotations.
    
    """
    
    foo = a.copy() # [a.pop(x) for x in ["creationDate", "etag", "id", "uri"]]
    a.update(b)
    return a

def updateAnnots(synid, lookupDict):
    """Update annotations using a dict to lookup which annotations to add (keys are synids).
    
    Works this way for parallelization.
    
    """
    logger.info("%s" % synid)
    o = syn.get(synid, downloadFile=False)
    a = syn.getAnnotations(o)
    newa = a.copy()
    newa = updateDict(newa, lookupDict[o.properties.id])
    foo = syn.setAnnotations(o, newa)

# %%
doupdate = True
updateDataTypes = dataTypes
# updateDataTypes = ['Teratoma']
_joinKey = "C4_Cell_Line_ID"

for dataType in updateDataTypes:
        
    # Metadata
    logger.info("Getting %s metadata" % dataType)
    metaSchema = syn.get(dataTypesToMetadataTable[dataType])
    metaResults = syn.tableQuery("select * from %s" % metaSchema.id)
    meta = metaResults.asDataFrame()
    
    # All files
    logger.info("Getting %s file list" % dataType)
    fileTbl = synapseHelpers.query2df(syn.chunkedQuery(dataTypesToQuery[dataType]), 
                                      filterSynapseFields=False)
        
    # Merge metadata and files
    logger.info("Merging %s" % dataType)
    
    merged = pd.merge(left=fileTbl[['id', _joinKey]],  right=meta,
                      how="left", left_on=_joinKey, right_on=_joinKey)
    
    merged.index = merged.id
    merged.drop("id", axis=1, inplace=True)
    merged.drop(_joinKey, axis=1, inplace=True)
        
    mergedDict = merged.transpose().to_dict()
    mergedDict2 = fixDict(mergedDict)

    # Update annotations
    if doupdate:
        logger.info("Updating %s annotations" % dataType)
        res = mp.map(lambda x: updateAnnots(x, mergedDict2), mergedDict2.keys())
# Out:
# INFO:pcbc update annots:Getting Karyotype metadata
#  [####################]100.00%     1/1  Done...
# Downloading  [####################]100.00%     39.8kB/39.8kB query_results.csv Done...
# Downloaded   [####################]100.00%     39.8kB/39.8kB query_results.csv Done...
# INFO:pcbc update annots:Getting Karyotype file list
# INFO:pcbc update annots:Merging Karyotype
# INFO:pcbc update annots:Updating Karyotype annotations
# INFO:pcbc update annots:syn2679209
# INFO:pcbc update annots:syn2679186
# INFO:pcbc update annots:syn2679180
# INFO:pcbc update annots:syn2679182
# INFO:pcbc update annots:syn2679184
# INFO:pcbc update annots:syn2679168
# INFO:pcbc update annots:syn2679166
# INFO:pcbc update annots:syn2679164
# INFO:pcbc update annots:syn2679162
# INFO:pcbc update annots:syn2679160
# INFO:pcbc update annots:syn2679187
# INFO:pcbc update annots:syn2679183
# INFO:pcbc update annots:syn2679185
# INFO:pcbc update annots:syn2679181
# INFO:pcbc update annots:syn2679165
# INFO:pcbc update annots:syn2679189
# INFO:pcbc update annots:syn2679169
# INFO:pcbc update annots:syn2679210
# INFO:pcbc update annots:syn2679212
# INFO:pcbc update annots:syn2679161
# INFO:pcbc update annots:syn2679211
# INFO:pcbc update annots:syn2679188
# INFO:pcbc update annots:syn2679203
# INFO:pcbc update annots:syn2679192
# INFO:pcbc update annots:syn2679163
# INFO:pcbc update annots:syn2679190
# INFO:pcbc update annots:syn2679213
# INFO:pcbc update annots:syn2679196
# INFO:pcbc update annots:syn2679194
# INFO:pcbc update annots:syn2679214
# INFO:pcbc update annots:syn2679170
# INFO:pcbc update annots:syn2679198
# INFO:pcbc update annots:syn2679193
# INFO:pcbc update annots:syn2679172
# INFO:pcbc update annots:syn2679191
# INFO:pcbc update annots:syn2679173
# INFO:pcbc update annots:syn2679195
# INFO:pcbc update annots:syn2679171
# INFO:pcbc update annots:syn2679174
# INFO:pcbc update annots:syn2679176
# INFO:pcbc update annots:syn2679197
# INFO:pcbc update annots:syn2679202
# INFO:pcbc update annots:syn2679200
# INFO:pcbc update annots:syn2679199
# INFO:pcbc update annots:syn2679206
# INFO:pcbc update annots:syn2679204
# INFO:pcbc update annots:syn2679177
# INFO:pcbc update annots:syn2679208
# INFO:pcbc update annots:syn2679175
# INFO:pcbc update annots:syn2679159
# INFO:pcbc update annots:syn2679178
# INFO:pcbc update annots:syn2679201
# INFO:pcbc update annots:syn2679207
# INFO:pcbc update annots:syn2679179
# INFO:pcbc update annots:syn2679205
# INFO:pcbc update annots:syn2679167
# INFO:pcbc update annots:Getting CNV metadata
# INFO:pcbc update annots:Getting CNV file list
# INFO:pcbc update annots:Merging CNV
# INFO:pcbc update annots:Updating CNV annotations
# INFO:pcbc update annots:syn2679137
# INFO:pcbc update annots:syn2679138
# INFO:pcbc update annots:syn2679155
# INFO:pcbc update annots:syn2679115
# INFO:pcbc update annots:syn2679144
# INFO:pcbc update annots:syn2679146
# INFO:pcbc update annots:syn2679126
# INFO:pcbc update annots:syn2679142
# INFO:pcbc update annots:syn2679128
# INFO:pcbc update annots:syn2679148
# INFO:pcbc update annots:syn2679117
# INFO:pcbc update annots:syn2679107
# INFO:pcbc update annots:syn2679125
# INFO:pcbc update annots:syn2679116
# INFO:pcbc update annots:syn2679149
# INFO:pcbc update annots:syn2679114
# INFO:pcbc update annots:syn2679127
# INFO:pcbc update annots:syn2679109
# INFO:pcbc update annots:syn2679129
# INFO:pcbc update annots:syn2679121
# INFO:pcbc update annots:syn2679106
# INFO:pcbc update annots:syn2679122
# INFO:pcbc update annots:syn2679120
# INFO:pcbc update annots:syn2679140
# INFO:pcbc update annots:syn2679118
# INFO:pcbc update annots:syn2679152
# INFO:pcbc update annots:syn2679150
# INFO:pcbc update annots:syn2679134
# INFO:pcbc update annots:syn2679136
# INFO:pcbc update annots:syn2679130
# INFO:pcbc update annots:syn2679145
# INFO:pcbc update annots:syn2679147
# INFO:pcbc update annots:syn2679156
# INFO:pcbc update annots:syn2679141
# INFO:pcbc update annots:syn2679153
# INFO:pcbc update annots:syn2679113
# INFO:pcbc update annots:syn2679111
# INFO:pcbc update annots:syn2679151
# INFO:pcbc update annots:syn2679131
# INFO:pcbc update annots:syn2679119
# INFO:pcbc update annots:syn2679132
# INFO:pcbc update annots:syn2679112
# INFO:pcbc update annots:syn2679135
# INFO:pcbc update annots:syn2679108
# INFO:pcbc update annots:syn2679139
# INFO:pcbc update annots:syn2679133
# INFO:pcbc update annots:syn2679154
# INFO:pcbc update annots:syn2679110
# INFO:pcbc update annots:syn2679124
# INFO:pcbc update annots:syn2679143
# INFO:pcbc update annots:Getting Teratoma metadata
# INFO:pcbc update annots:Getting Teratoma file list
# INFO:pcbc update annots:Merging Teratoma
# INFO:pcbc update annots:Updating Teratoma annotations
# INFO:pcbc update annots:syn5758393
# INFO:pcbc update annots:syn2884713
# INFO:pcbc update annots:syn5752418
# INFO:pcbc update annots:syn2884791
# INFO:pcbc update annots:syn5752366
# INFO:pcbc update annots:syn5735204
# INFO:pcbc update annots:syn2885180
# INFO:pcbc update annots:syn2885108
# INFO:pcbc update annots:syn5752407
# INFO:pcbc update annots:syn5757522
# INFO:pcbc update annots:syn2885130
# INFO:pcbc update annots:syn5758522
# INFO:pcbc update annots:syn5758394
# INFO:pcbc update annots:syn5752414
# INFO:pcbc update annots:syn5752367
# INFO:pcbc update annots:syn2885104
# INFO:pcbc update annots:syn5735053
# INFO:pcbc update annots:syn5757881
# INFO:pcbc update annots:syn2885228
# INFO:pcbc update annots:syn5758301
# INFO:pcbc update annots:syn2885135
# INFO:pcbc update annots:syn5758552
# INFO:pcbc update annots:syn5758251
# INFO:pcbc update annots:syn5752364
# INFO:pcbc update annots:syn5758315
# INFO:pcbc update annots:syn5752363
# INFO:pcbc update annots:syn5735196
# INFO:pcbc update annots:syn5721667
# INFO:pcbc update annots:syn5752372
# INFO:pcbc update annots:syn5721466
# INFO:pcbc update annots:syn5735206
# INFO:pcbc update annots:syn5758413
# INFO:pcbc update annots:syn2885137
# INFO:pcbc update annots:syn5752377
# INFO:pcbc update annots:syn5752408
# INFO:pcbc update annots:syn5758521
# INFO:pcbc update annots:syn2885186
# INFO:pcbc update annots:syn5757523
# INFO:pcbc update annots:syn5752361
# INFO:pcbc update annots:syn5752412
# INFO:pcbc update annots:syn2885192
# INFO:pcbc update annots:syn2884737
# INFO:pcbc update annots:syn5757497
# INFO:pcbc update annots:syn2884808
# INFO:pcbc update annots:syn5758541
# INFO:pcbc update annots:syn5757967
# INFO:pcbc update annots:syn5757869
# INFO:pcbc update annots:syn2884755
# INFO:pcbc update annots:syn2885170
# INFO:pcbc update annots:syn5757873
# INFO:pcbc update annots:syn2885194
# INFO:pcbc update annots:syn2884730
# INFO:pcbc update annots:syn5713304
# INFO:pcbc update annots:syn5735074
# INFO:pcbc update annots:syn5735261
# INFO:pcbc update annots:syn5758228
# INFO:pcbc update annots:syn5757970
# INFO:pcbc update annots:syn2884818
# INFO:pcbc update annots:syn5721489
# INFO:pcbc update annots:syn5758349
# INFO:pcbc update annots:syn5705324
# INFO:pcbc update annots:syn5758231
# INFO:pcbc update annots:syn2885164
# INFO:pcbc update annots:syn2885116
# INFO:pcbc update annots:syn5758299
# INFO:pcbc update annots:syn5713111
# INFO:pcbc update annots:syn5758598
# INFO:pcbc update annots:syn2884800
# INFO:pcbc update annots:syn2885223
# INFO:pcbc update annots:syn5713101
# INFO:pcbc update annots:syn5713315
# INFO:pcbc update annots:syn5758621
# INFO:pcbc update annots:syn2885160
# INFO:pcbc update annots:syn2884810
# INFO:pcbc update annots:syn5735267
# INFO:pcbc update annots:syn5758508
# INFO:pcbc update annots:syn5713094
# INFO:pcbc update annots:syn2885176
# INFO:pcbc update annots:syn5713105
# INFO:pcbc update annots:syn2884721
# INFO:pcbc update annots:syn5757517
# INFO:pcbc update annots:syn5721442
# INFO:pcbc update annots:syn2885215
# INFO:pcbc update annots:syn2885146
# INFO:pcbc update annots:syn5752356
# INFO:pcbc update annots:syn5713407
# INFO:pcbc update annots:syn5758378
# INFO:pcbc update annots:syn5758474
# INFO:pcbc update annots:syn5757850
# INFO:pcbc update annots:syn5758385
# INFO:pcbc update annots:syn5721446
# INFO:pcbc update annots:syn5721594
# INFO:pcbc update annots:syn2884744
# INFO:pcbc update annots:syn5758354
# INFO:pcbc update annots:syn5757503
# INFO:pcbc update annots:syn2885201
# INFO:pcbc update annots:syn2885153
# INFO:pcbc update annots:syn5758361
# INFO:pcbc update annots:syn5722157
# INFO:pcbc update annots:syn2884767
# INFO:pcbc update annots:syn2885128
# INFO:pcbc update annots:syn5757765
# INFO:pcbc update annots:syn2885142
# INFO:pcbc update annots:syn5757974
# INFO:pcbc update annots:syn5757829
# INFO:pcbc update annots:syn2884777
# INFO:pcbc update annots:syn5734940
# INFO:pcbc update annots:syn2885151
# INFO:pcbc update annots:syn5758572
# INFO:pcbc update annots:syn5735265
# INFO:pcbc update annots:syn2885149
# INFO:pcbc update annots:syn5758565
# INFO:pcbc update annots:syn2885206
# INFO:pcbc update annots:syn5721440
# INFO:pcbc update annots:syn2885156
# INFO:pcbc update annots:syn5757851
# INFO:pcbc update annots:syn5735069
# INFO:pcbc update annots:syn5752358
# INFO:pcbc update annots:syn5752384
# INFO:pcbc update annots:syn2885110
# INFO:pcbc update annots:syn5758545
# INFO:pcbc update annots:syn2885125
# INFO:pcbc update annots:syn5758461
# INFO:pcbc update annots:syn5721473
# INFO:pcbc update annots:syn5721606
# INFO:pcbc update annots:syn5758375
# INFO:pcbc update annots:syn5713223
